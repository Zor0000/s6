# %%
# Neeraj Chormale - 20220802071

def print_board(board):
    for row in board:
        print(" | ".join(row))
        print("-" * (len(board) * 4 - 3))

def check_winner(board, player):
    size = len(board)

    # Check rows and columns
    for i in range(size):
        if all([cell == player for cell in board[i]]) or all([board[j][i] == player for j in range(size)]):
            return True

    # Check diagonals
    if all([board[i][i] == player for i in range(size)]) or all([board[i][size - i - 1] == player for i in range(size)]):
        return True

    return False

def is_full(board):
    return all(cell != " " for row in board for cell in row)

def play_game(size=3):
    board = [[" " for _ in range(size)] for _ in range(size)]
    players = ["X", "O"]
    turn = 0

    while True:
        print_board(board)
        player = players[turn % 2]
        print(f"Player {player}'s turn")

        try:
            row = int(input(f"Enter row (0 to {size-1}): "))
            col = int(input(f"Enter col (0 to {size-1}): "))
        except ValueError:
            print("Invalid input. Please enter numeric indices.")
            continue

        if 0 <= row < size and 0 <= col < size and board[row][col] == " ":
            board[row][col] = player
            if check_winner(board, player):
                print_board(board)
                print(f"Player {player} wins!")
                break
            elif is_full(board):
                print_board(board)
                print("It's a draw!")
                break
            turn += 1
        else:
            print("Invalid move. Try again.")

print("3x3 Tic-Tac-Toe")
play_game(3)
# Out:
# 3x3 Tic-Tac-Toe
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Player X's turn
# Enter row (0 to 2): 0
# Enter col (0 to 2): 1
#   | X |
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Player O's turn
# Enter row (0 to 2): 2
# Enter col (0 to 2): 2
#   | X |
# ---------
#   |   |
# ---------
#   |   | O
# ---------
# Player X's turn
# Enter row (0 to 2): 0
# Enter col (0 to 2): 0
# X | X |
# ---------
#   |   |
# ---------
#   |   | O
# ---------
# Player O's turn
# Enter row (0 to 2): 0
# Enter col (0 to 2): 2
# X | X | O
# ---------
#   |   |
# ---------
#   |   | O
# ---------
# Player X's turn
# Enter row (0 to 2): 1
# Enter col (0 to 2): 2
# X | X | O
# ---------
#   |   | X
# ---------
#   |   | O
# ---------
# Player O's turn
# Enter row (0 to 2): 2
# Enter col (0 to 2): 0
# X | X | O
# ---------
#   |   | X
# ---------
# O |   | O
# ---------
# Player X's turn
# Enter row (0 to 2): 2
# Enter col (0 to 2): 1
# X | X | O
# ---------
#   |   | X
# ---------
# O | X | O
# ---------
# Player O's turn
# Enter row (0 to 2): 1
# Enter col (0 to 2): 1
# X | X | O
# ---------
#   | O | X
# ---------
# O | X | O
# ---------
# Player O wins!

# %% [markdown]
# #Practice

# %%
    def print_board(board):
        for row in board:
            print(" | ".join(row))
            print("-" * (len(board) * 4 - 3))

    def check_winner(board, player):
        size = len(board)

        # Check rows and columns
        for i in range(size):
            if all([cell == player for cell in board[i]]) or all([board[j][i] == player for j in range(size)]):
                return True

        # Check diagonals
        if all([board[i][i] == player for i in range(size)]) or all([board[i][size - i - 1] == player for i in range(size)]):
            return True

        return False

    def is_full(board):
        return all(cell != " " for row in board for cell in row)

    def play_game():
        try:
            size = int(input("Enter board size (e.g., 3 for 3x3, 4 for 4x4): "))
            if size < 3:
                print("Board size should be 3 or more.")
                return
        except ValueError:
            print("Invalid input. Please enter a number.")
            return

        board = [[" " for _ in range(size)] for _ in range(size)]
        players = ["X", "O"]
        turn = 0

        while True:
            print_board(board)
            player = players[turn % 2]
            print(f"Player {player}'s turn")

            try:
                row = int(input(f"Enter row (0 to {size-1}): "))
                col = int(input(f"Enter col (0 to {size-1}): "))
            except ValueError:
                print("Invalid input. Please enter numeric indices.")
                continue

            if 0 <= row < size and 0 <= col < size and board[row][col] == " ":
                board[row][col] = player
                if check_winner(board, player):
                    print_board(board)
                    print(f"Player {player} wins!")
                    break
                elif is_full(board):
                    print_board(board)
                    print("It's a draw!")
                    break
                turn += 1
            else:
                print("Invalid move. Try again.")

    # Run the game
    play_game()
# Out:
# Enter board size (e.g., 3 for 3x3, 4 for 4x4): 3
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Player X's turn
# Enter row (0 to 2): 0
# Enter col (0 to 2): 0
# X |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Player O's turn
# Enter row (0 to 2): 2
# Enter col (0 to 2): 2
# X |   |
# ---------
#   |   |
# ---------
#   |   | O
# ---------
# Player X's turn
# Enter row (0 to 2): 0
# Enter col (0 to 2): 1
# X | X |
# ---------
#   |   |
# ---------
#   |   | O
# ---------
# Player O's turn
# Enter row (0 to 2): 2
